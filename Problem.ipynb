# %% [markdown]
# <a href="https://colab.research.google.com/github/tharanivm/AIML-PREREQ-LEARNER/blob/main/Problem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=input()
print(a)
# Out:
# 12345
# 12345
